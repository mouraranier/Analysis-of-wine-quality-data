# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('winequality/winequality-red.csv', sep = ";")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Select four features and then compute: mean, mode, median, percentile (20, 50 and 70), quartile (Q1, Q2 and Q3), variance and standard deviation

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#média

media_density = np.mean(df["density"])
media_pH = np.mean(df["pH"])
media_residual_sugar = np.mean(df["residual sugar"])
media_chlorides = np.mean(df["chlorides"])

media_density, media_pH, media_residual_sugar, media_chlorides
# Out:
# (0.9967466791744841, 3.3111131957473416, 2.53880550343965, 0.08746654158849279)

# %%
#moda

moda_density = stats.mode(df["density"])
moda_pH = stats.mode(df["pH"])
moda_residual_sugar = stats.mode(df["residual sugar"])
moda_chlorides = stats.mode(df["chlorides"])

moda_density, moda_pH, moda_residual_sugar, moda_chlorides
# Out:
# (ModeResult(mode=array([0.9972]), count=array([36])),
#  ModeResult(mode=array([3.3]), count=array([57])),
#  ModeResult(mode=array([2.]), count=array([156])),
#  ModeResult(mode=array([0.08]), count=array([66])))

# %%
#mediana

mediana_density = np.median(df["density"])
mediana_pH = np.median(df["pH"])
mediana_residual_sugar = np.median(df["residual sugar"])
mediana_chlorides = np.median(df["chlorides"])

mediana_density, mediana_pH, mediana_residual_sugar, mediana_chlorides
# Out:
# (0.99675, 3.31, 2.2, 0.079)

# %%
#percentis 20

percentis20_density = np.percentile(df["density"], 20)
percentis20_pH = np.percentile(df["pH"], 20)
percentis20_residual_sugar = np.percentile(df["residual sugar"], 20)
percentis20_chlorides = np.percentile(df["chlorides"], 20)

percentis20_density, percentis20_pH, percentis20_residual_sugar, percentis20_chlorides
# Out:
# (0.99534, 3.18, 1.8, 0.067)

# %%
#percentis 50
#igual a mediana

percentis50_density = np.percentile(df["density"], 50)
percentis50_pH = np.percentile(df["pH"], 50)
percentis50_residual_sugar = np.percentile(df["residual sugar"], 50)
percentis50_chlorides = np.percentile(df["chlorides"], 50)

percentis50_density, percentis50_pH, percentis50_residual_sugar, percentis50_chlorides
# Out:
# (0.99675, 3.31, 2.2, 0.079)

# %%
#percentis 70

percentis70_density = np.percentile(df["density"], 70)
percentis70_pH = np.percentile(df["pH"], 70)
percentis70_residual_sugar = np.percentile(df["residual sugar"], 70)
percentis70_chlorides = np.percentile(df["chlorides"], 70)

percentis70_density, percentis70_pH, percentis70_residual_sugar, percentis70_chlorides
# Out:
# (0.9976, 3.38, 2.5, 0.087)

# %%
#Quartil Q1
#Quartil Q2 igual a mediana e igual ao percentil 50

quartilQ1_density = np.percentile(df["density"], 25)
quartilQ1_pH = np.percentile(df["pH"], 25)
quartilQ1_residual_sugar = np.percentile(df["residual sugar"], 25)
quartilQ1_chlorides = np.percentile(df["chlorides"], 25)

quartilQ1_density, quartilQ1_pH, quartilQ1_residual_sugar, quartilQ1_chlorides
# Out:
# (0.9956, 3.21, 1.9, 0.07)

# %%
#Quartil Q3

quartilQ3_density = np.percentile(df["density"], 75)
quartilQ3_pH = np.percentile(df["pH"], 75)
quartilQ3_residual_sugar = np.percentile(df["residual sugar"], 75)
quartilQ3_chlorides = np.percentile(df["chlorides"], 75)

quartilQ3_density, quartilQ3_pH, quartilQ3_residual_sugar, quartilQ3_chlorides
# Out:
# (0.997835, 3.4, 2.6, 0.09)

# %%
#variancia

variancia_density = np.var(df["density"])
variancia_pH = np.var(df["pH"])
variancia_residual_sugar = np.var(df["residual sugar"])
variancia_chlorides = np.var(df["chlorides"])

variancia_density, variancia_pH, variancia_residual_sugar, variancia_chlorides
# Out:
# (3.5598017926307083e-06,
#  0.023820274241131787,
#  1.9866539202698996,
#  0.0022137573233114347)

# %%
#desvio padrão

desviopadrao_density = np.std(df["density"])
desviopadrao_pH = np.std(df["pH"])
desviopadrao_residual_sugar = np.std(df["residual sugar"])
desviopadrao_chlorides = np.std(df["chlorides"])

desviopadrao_density, desviopadrao_pH, desviopadrao_residual_sugar, desviopadrao_chlorides
# Out:
# (0.0018867437008323914,
#  0.15433818141060165,
#  1.4094871124880495,
#  0.04705058260331571)

# %% [markdown]
# # Create boxplots and then identify outliers

# %%
plt.figure(figsize=(6, 6))
plt.style.use('seaborn')
plt.boxplot(df["density"])
plt.title("Density")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.boxplot(df["pH"])
plt.title("pH")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.boxplot(df["residual sugar"])
plt.title("Residual Sugar")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.boxplot(df["chlorides"])
plt.title("Chlorides")
plt.show()

# %% [markdown]
# # Create histograms

# %%
#o numero de classes k se deu através da raíz da qtd de amostras

plt.figure(figsize=(6, 6))
plt.title('Density', fontsize = 14)
plt.xlabel('Density')
plt.ylabel('Frequency')
plt.hist(df["density"], 40, rwidth=0.9)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title('pH', fontsize = 14)
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.hist(df["pH"], 40, rwidth=0.9)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title('Residual Sugar', fontsize = 14)
plt.xlabel('Residual Sugar')
plt.ylabel('Frequency')
plt.hist(df["residual sugar"], 40, rwidth=0.9)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title('Chlorides', fontsize = 14)
plt.xlabel('Chlorides')
plt.ylabel('Frequency')
plt.hist(df["chlorides"], 40, rwidth=0.9)
plt.show()

# %% [markdown]
# # Create scatter plots considering pairs of features

# %%
#combinacao 2 a 2 de 4 elementos eh igual a 6


plt.figure(figsize=(6, 6))
plt.title('Density vs. pH', fontsize = 14)
plt.scatter(df["density"], df["pH"], alpha=0.5)
plt.xlabel('Density')
plt.ylabel('pH')
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title('Density vs. Residual Sugar', fontsize = 14)
plt.scatter(df["density"], df["residual sugar"], alpha=0.5)
plt.xlabel('Density')
plt.ylabel('Residual Sugar')
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title('Density vs. Chlorides', fontsize = 14)
plt.scatter(df["density"], df["chlorides"], alpha=0.5)
plt.xlabel('Density')
plt.ylabel('Chlorides')
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title('pH vs. Residual Sugar', fontsize = 14)
plt.scatter(df["pH"], df["residual sugar"], alpha=0.5)
plt.xlabel('pH')
plt.ylabel('Residual Sugar')
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title('pH vs. Chlorides', fontsize = 14)
plt.scatter(df["pH"], df["chlorides"], alpha=0.5)
plt.xlabel('pH')
plt.ylabel('Chlorides')
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.title('Residual Sugar vs. Chlorides', fontsize = 14)
plt.scatter( df["residual sugar"], df["chlorides"], alpha=0.5)
plt.xlabel('Residual Sugar')
plt.ylabel('Chlorides')
plt.show()

# %% [markdown]
# # Compute the covariance and correlation matrices

# %%
matriz_cov = pd.DataFrame(np.cov(df, rowvar = False), 
                          columns = ['fixed acidity','volatile acidity','citric acid','residual sugar',
                                     'chlorides','free sulfur dioxide','total sulfur dioxide','density',
                                     'pH','sulphates','alcohol','quality'],
                         index = ['fixed acidity','volatile acidity','citric acid','residual sugar',
                                     'chlorides','free sulfur dioxide','total sulfur dioxide','density',
                                     'pH','sulphates','alcohol','quality'])

print(matriz_cov.shape)
matriz_cov = matriz_cov.round(4)
matriz_cov
# Out:
# (12, 12)
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                3.0314           -0.0799       0.2278
# volatile acidity            -0.0799            0.0321      -0.0193
# citric acid                  0.2278           -0.0193       0.0379
# residual sugar               0.2818            0.0005       0.0394
# chlorides                    0.0077            0.0005       0.0019
# free sulfur dioxide         -2.8009           -0.0197      -0.1243
# total sulfur dioxide        -6.4823            0.4504       0.2277
# density                      0.0022            0.0000       0.0001
# pH                          -0.1836            0.0065      -0.0163
# sulphates                    0.0540           -0.0079       0.0103
# alcohol                     -0.1144           -0.0386       0.0228
# quality                      0.1744           -0.0565       0.0356
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
print(matriz_cov.to_latex(index=True))
# Out:
# \begin{tabular}{lrrrrrrrrrrrr}
# \toprule
# {} &  fixed acidity &  volatile acidity &  citric acid &  residual sugar &  chlorides &  free sulfur dioxide &  total sulfur dioxide &  density &      pH &  sulphates &  alcohol &  quality \\
# \midrule
# fixed acidity        &         3.0314 &           -0.0799 &       0.2278 &          0.2818 &     0.0077 &              -2.8009 &               -6.4823 &   0.0022 & -0.1836 &     0.0540 &  -0.1144 &   0.1744 \\
# volatile acidity     &        -0.0799 &            0.0321 &      -0.0193 &          0.0005 &     0.0005 &              -0.0197 &                0.4504 &   0.0000 &  0.0065 &    -0.0079 &  -0.0386 &  -0.0565 \\
# citric acid          &         0.2278 &           -0.0193 &       0.0379 &          0.0394 &     0.0019 &              -0.1243 &                0.2277 &   0.0001 & -0.0163 &     0.0103 &   0.0228 &   0.0356 \\
# ...

# %%
matriz_corr = df.corr()
matriz_corr = matriz_corr.round(4)
matriz_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                1.0000           -0.2561       0.6717
# volatile acidity            -0.2561            1.0000      -0.5525
# citric acid                  0.6717           -0.5525       1.0000
# residual sugar               0.1148            0.0019       0.1436
# chlorides                    0.0937            0.0613       0.2038
# free sulfur dioxide         -0.1538           -0.0105      -0.0610
# total sulfur dioxide        -0.1132            0.0765       0.0355
# density                      0.6680            0.0220       0.3649
# pH                          -0.6830            0.2349      -0.5419
# sulphates                    0.1830           -0.2610       0.3128
# alcohol                     -0.0617           -0.2023       0.1099
# quality                      0.1241           -0.3906       0.2264
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...
